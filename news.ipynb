# %% [markdown]
# ### Importing Modules

# %%
import pandas as pd #for importing dataset
import numpy as nm #for doing mathematical operations 
from sklearn.model_selection import train_test_split as ttp #to break dataset for training and testing
from sklearn.metrics import classification_report # to generate classification report
import re #for data cleaning purpose
import string #to deal with text data
import matplotlib.pyplot as plt #for visualizing dataset

# %% [markdown]
# ### Reading two  data files
# ### Downloaded this dataset from
# https://www.kaggle.com/code/therealsampat/fake-news-detection/data

# %%
data_true=pd.read_csv("True.csv")
data_fake=pd.read_csv("Fake.csv")

# %% [markdown]
# #### Printing top 5 values from both Dataset

# %%
data_true.head(5)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
data_fake.head(9)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# 5  The number of cases of cops brutalizing and ki...    News
# 6  Donald Trump spent a good portion of his day a...    News
# 7  In the wake of yet another court decision that...    News
# 8  Many people have raised the alarm regarding th...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017
# 5  December 25, 2017
# 6  December 23, 2017
# 7  December 23, 2017
# 8  December 22, 2017

# %% [markdown]
# #### Checking size of Datasets

# %%
data_true.shape, data_fake.shape
# Out:
# ((21417, 4), (23481, 4))

# %% [markdown]
# ### Adding column name "class" in both datasets

# %%
data_true["class"]=1
data_fake["class"]=0

# %% [markdown]
# ###  Taking last 10 values for manual testing from both Datasets

# %%
data_true_manual_testing = data_true.tail(10)
for i in range(21416,21406,-1):
    data_true.drop([i],axis=0, inplace=True)#removing those 10 values from original dataset
    
data_fake_manual_testing = data_fake.tail(10)
for i in range(21416,21406,-1):
    data_fake.drop([i],axis=0, inplace=True)#removing those 10 values from original dataset

# %% [markdown]
# ### merging these two datasets in single dataframe

# %%
data_manual_testing = pd.concat([data_fake_manual_testing, data_true_manual_testing], axis=0)
data_manual_testing.to_csv("manual_testing.csv ")

# %% [markdown]
# ### Merging main two datasets

# %%
data_merge = pd.concat([data_fake,data_true],axis=0)
data_merge.head(10)#displaying first 10 values after above operation
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# 5  The number of cases of cops brutalizing and ki...    News
# 6  Donald Trump spent a good portion of his day a...    News
# 7  In the wake of yet another court decision that...    News
# 8  Many people have raised the alarm regarding th...    News
# 9  Just when you might have thought we d get a br...    News
#
#                 date  class
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0
# 5  December 25, 2017      0
# 6  December 23, 2017      0
# 7  December 23, 2017      0
# 8  December 22, 2017      0
# 9  December 21, 2017      0

# %% [markdown]
# ### Performing some basic data visualizations

# %%
print(data_merge.groupby(['subject'])['text'].count())
plt.figure(figsize=(6, 2))
data_merge.groupby(['subject'])['text'].count().plot(kind="bar")
plt.title("Articles per subject",size=20)
plt.xlabel("Category",size=20)
plt.ylabel("Article count",size=20)
plt.show()
# Out:
# subject
# Government News     1570
# Middle-east          778
# News                9050
# US_News              783
# left-news           4449
# politics            6841
# politicsNews       11272
# worldnews          10135
# Name: text, dtype: int64

# %%
print(data_merge.groupby(['class'])['text'].count())
f = plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
print("0 = Fake news\n1 = True news")
data_merge.groupby(['class'])['text'].count().plot(kind="pie")
plt.title("Fake news and True News",size=20)

plt.show()
# Out:
# class
# 0    23471
# 1    21407
# Name: text, dtype: int64
# 0 = Fake news
# 1 = True news

# %% [markdown]
# ### Removing 3 columns from dataset

# %%
data = data_merge.drop(["title","subject","date"], axis=1)
data.head(10)
# Out:
#                                                 text  class
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0
# 5  The number of cases of cops brutalizing and ki...      0
# 6  Donald Trump spent a good portion of his day a...      0
# 7  In the wake of yet another court decision that...      0
# 8  Many people have raised the alarm regarding th...      0
# 9  Just when you might have thought we d get a br...      0

# %% [markdown]
# ### Shuffling the dataset for better prediction

# %%
data=data.sample(frac=1)
data.head(10)
# Out:
#                                                     text  class
# 11698  A federal appeals court ruled that the U.S. wi...      0
# 17744  BEIRUT (Reuters) - Lebanon s Hezbollah group d...      1
# 9836   Pittsburgh Steelers players were absent from t...      0
# 21345  BANGKOK (Reuters) - Ousted Thai prime minister...      1
# 9768   Anyone who is not yet convinced that liberalis...      0
# 6405   George Zimmerman, the infamous neighborhood wa...      0
# 16788  VALLETTA (Reuters) - Thousands of Maltese call...      1
# 20092  This new information just adds more validity T...      0
# 19535  Kellogg Co. is pulling its ads from the websit...      0
# 20263  Who better to help root out terror than a pers...      0

# %% [markdown]
# ### Checking for null values in dataset

# %%
data.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %% [markdown]
# ### Creating data filtering function to remove unwanted data from text

# %%
def filtering(data):
    text=data.lower()
    text=re.sub(r'\[.*?\]','',text)
    text=re.sub(r"\\W"," ",text)
    text=re.sub(r'https?://\s+|www\.S+','',text)
    text=re.sub(r'<.*?>+','',text)
    text=re.sub(r'[%s]'% re.escape(string.punctuation),'',text)
    text=re.sub(r'\w*\d\w*','',text)
    return text

# %% [markdown]
# ### Filtering data of our text column using above function

# %%
data["text"]= data["text"].apply(filtering)
data.head(10)
# Out:
#                                                     text  class
# 11698  a federal appeals court ruled that the us will...      0
# 17744  beirut reuters  lebanon s hezbollah group dism...      1
# 9836   pittsburgh steelers players were absent from t...      0
# 21345  bangkok reuters  ousted thai prime minister yi...      1
# 9768   anyone who is not yet convinced that liberalis...      0
# 6405   george zimmerman the infamous neighborhood wat...      0
# 16788  valletta reuters  thousands of maltese called ...      1
# 20092  this new information just adds more validity t...      0
# 19535  kellogg co is pulling its ads from the website...      0
# 20263  who better to help root out terror than a pers...      0

# %% [markdown]
# ### Creating Dependent and independant variables

# %%
x=data["text"]
y=data["class"]

# %% [markdown]
# ### Splitting dataset for training and testing purpose

# %%
x_train,x_test,y_train,y_test=ttp(x,y,test_size=0.25,random_state=0)

# %% [markdown]
# ### Vectorizing the text
#
# #### The sklearn. feature_extraction module is used to extract features in a format supported by machine learning algorithms from datasets consisting of formats such as text and image

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vector = TfidfVectorizer() # creating object 

xv_train=vector.fit_transform(x_train)
xv_test=vector.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Classifaction using various classifiers

# %% [markdown]
# ### Logistic Regression
# #### Calculating probability of event occurence

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR=LogisticRegression()
LR.fit(xv_train,y_train) #training or fitting the model to the training set
# Out:
# LogisticRegression()

# %%
import joblib
joblib.dump(LR, 'model.pkl')
# Out:
# ['model.pkl']

# %%
accuracy = round(LR.score(xv_test, y_test), 2)
print(accuracy)
# Out:
# 0.99

# %%
pred_LR= LR.predict(xv_test) # Predict using the linear model

# %%
print(classification_report(y_test,pred_LR)) #creating classification report
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5772
#            1       0.98      0.99      0.99      5448
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %% [markdown]
# ### Confusion matrix
# #### determine the performance of the classification models for a given set of test data.

# %%
from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test,pred_LR)  
print(cm)
import seaborn as sns
sns.heatmap(cm,cmap="BuPu",annot=True,fmt='d')
plt.xlabel("Predicted Label")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# [[5687   85]
#  [  77 5371]]

# %% [markdown]
# ### Decision Tree Classification

# %% [markdown]
# #### Non-parametric supervised learning method used for both classification and regression tasks.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT = DecisionTreeClassifier()
DT.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
accuracy = round(DT.score(xv_test, y_test), 2)
print(f"Accuracy of Decision Tree: {accuracy}")
# Out:
# Accuracy of Decision Tree: 1.0

# %%
pred_DT = DT.predict(xv_test)

# %%
print(classification_report(y_test,pred_DT))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5772
#            1       1.00      1.00      1.00      5448
#
#     accuracy                           1.00     11220
#    macro avg       1.00      1.00      1.00     11220
# weighted avg       1.00      1.00      1.00     11220

# %%
cm= confusion_matrix(y_test,pred_DT)  
print(cm)
import seaborn as sns
sns.heatmap(cm,cmap="PiYG",annot=True,fmt='d')
plt.xlabel("Predicted Label")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# [[5745   27]
#  [  24 5424]]

# %% [markdown]
# ### Gradient Boosting Classifier

# %% [markdown]
# #### It is a group of machine learning algorithms that combine many weak learning models together to create a strong predictive model.

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
GBC = GradientBoostingClassifier(random_state=0)
GBC.fit(xv_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
GBC.score(xv_test,y_test)
# Out:
# 0.9944741532976827

# %%
pred_GBC = GBC.predict(xv_test)

# %%
print(classification_report(y_test,pred_GBC))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      5772
#            1       0.99      1.00      0.99      5448
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %%
cm= confusion_matrix(y_test,pred_GBC)  
print(cm)
import seaborn as sns
sns.heatmap(cm,cmap="Greens",annot=True,fmt='d')
plt.xlabel("Predicted Label")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# [[5729   43]
#  [  19 5429]]

# %% [markdown]
# ### Random Forest Classifier

# %% [markdown]
# #### Supervised Machine learning algorithm used for classification, regression, and other tasks using decision trees

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFC = RandomForestClassifier(random_state=0)
RFC.fit(xv_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
RFC.score(xv_test,y_test)
# Out:
# 0.9859180035650624

# %%
pred_RFC = RFC.predict(xv_test)

# %%
print(classification_report(y_test,pred_RFC))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      5772
#            1       0.99      0.98      0.99      5448
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %%
cm= confusion_matrix(y_test,pred_RFC)  
print(cm)
import seaborn as sns
sns.heatmap(cm,cmap="Blues",annot=True,fmt='d')
plt.xlabel("Predicted Label")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# [[5703   69]
#  [  89 5359]]

# %%
import joblib



joblib.dump(vector, 'vectorizer.pkl')
# Out:
# ['vectorizer.pkl']

# %% [markdown]
# ## Manual Testing

# %%
def output_lable(n):
    if n == 0:
        return "FAKE News"
    elif n == 1:
        return "TRUE News"
    
def manual_testing(news):
    testing_news = {"text":[news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(filtering) 
    new_x_test = new_def_test["text"]
    new_xv_test = vector.transform(new_x_test)
    pred_LR = LR.predict(new_xv_test)
    pred_DT = DT.predict(new_xv_test)
    pred_GBC = GBC.predict(new_xv_test)
    pred_RFC = RFC.predict(new_xv_test)

    return print("\n\nLR Prediction: {} \nDT Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(output_lable(pred_LR[0]),
                                                                                                              output_lable(pred_DT[0]), 
                                                                                                              output_lable(pred_GBC[0]), 
                                                                                                              output_lable(pred_RFC[0])))

# %%
news = str(input())
manual_testing(news)
